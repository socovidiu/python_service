# %%
import requests

# %%
response = requests.get("https://wttr.in/Cluj")

# %%
response
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# Weather report: Cluj
#
#       \   /     Sunny
#        .-.      27 °C
#     ― (   ) ―   ↘ 17 km/h
#        `-’      10 km
#       /   \     0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 01 Jul ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │     \   /     Sunny          │     \   /     Sunny          │     \   /     Sunny          │
# │      .-.      20 °C          │      .-.      +24(25) °C     │      .-.      24 °C          │      .-.      +15(14) °C     │
# │   ― (   ) ―   ↘ 17-19 km/h   │   ― (   ) ―   ↘ 20-23 km/h   │   ― (   ) ―   ↘ 22-25 km/h   │   ― (   ) ―   → 12-26 km/h   │
# ...
